# %%
import pymongo
import numpy as np
import pandas as pd
from bson import ObjectId

# %%
MONGODB_URI = 'mongodb://looxidlabs:looxidlabs.vkdlxld%21@3.36.42.241:39632/m-project-dev?authSource=admin&readPreference=primary&appname=MongoDB%20Compass&directConnection=true&ssl=false'

# %%
client = pymongo.MongoClient(MONGODB_URI)

focus_mate = client['focusmate']

focus_timer = focus_mate['focustimers']
focus_timer_records = focus_mate['focustimerrecords']

# %%
user_id = ObjectId('6549ea169113bf9e08eb3c12')

# %%
user_focus_timer_list = list(focus_timer.find({'userId' : user_id, 'withBand' : True}))

# %%
user_focus_timer_list.reverse()

# %%
user_focus_timer_list
# Out:
# [{'_id': ObjectId('65b242cf1f3ff946c2c1d31c'),
#   'userId': ObjectId('6549ea169113bf9e08eb3c12'),
#   'goalId': ObjectId('65b242cc1f3ff946c2c1d312'),
#   'time': 5792,
#   'pureFocusTime': 0,
#   'pauseTime': 0,
#   'recordCount': 49,
#   'efficiency': 33.337421718024196,
#   'efficiencies': [39.77155698709691,
#    29.144701319724316,
#    30.96503043760205,
#    31.091180992209406,
#    41.39617977478925,
#    33.41527381095738,
#    35.39793719249128,
#    29.239652141869726,
#    31.02856518210643,
#    36.318877253269655,
#    34.44415866297221,
#    35.12538336926532,
#    32.473154061315235,
#    33.81040431965064,
#    33.60858378263145,
#    33.43145472286115,
#    32.27418796917721,
#    33.8739735783842,
#    30.180563219942023,
#    31.48122594387662],
#   'efficiencyVHCount': 7,
#   'efficiencyHCount': 10,
#   'efficiencyMCount': 30,
#   'efficiencyLCount': 246,
#   'capacity': 0,
#   'stress': 0,
#   'interruptedCount': 0,
#   'interruptedCountInApp': 0,
# ...

# %%
focus_timer_focus_id = user_focus_timer_list[0]['_id']
focus_timer_user_id = user_focus_timer_list[0]['userId']

# %%
sepcific_focus_timer_records_list = list(focus_timer_records.find({'focusTimerId' : focus_timer_focus_id}))

# %%
focus_timer_focus_id
# Out:
# ObjectId('65b242cf1f3ff946c2c1d31c')

# %%
sepcific_focus_timer_records_list
# Out:
# [{'_id': ObjectId('65b2430b1f3ff946c2c1d322'),
#   'capacity': 0,
#   'createdAt': datetime.datetime(2024, 1, 25, 11, 16, 32, 833000),
#   'efficiencies': [42.93980099241144,
#    52.47654442972417,
#    53.5756687089743,
#    40.370281222546424,
#    63.35928736643706,
#    45.148810151436194],
#   'focusTimerId': ObjectId('65b242cf1f3ff946c2c1d31c'),
#   'index': 0,
#   'stress': 0},
#  {'_id': ObjectId('65b243471f3ff946c2c1d327'),
#   'capacity': 0,
#   'createdAt': datetime.datetime(2024, 1, 25, 11, 17, 29, 331000),
#   'efficiencies': [32.92875551062562,
#    32.16874895459389,
#    29.03534555624791,
#    29.455512927561116,
#    36.556629911047736,
#    36.00721385531362],
#   'focusTimerId': ObjectId('65b242cf1f3ff946c2c1d31c'),
#   'index': 1,
#   'stress': 0},
#  {'_id': ObjectId('65b243831f3ff946c2c1d32c'),
#   'capacity': 0,
#   'createdAt': datetime.datetime(2024, 1, 25, 11, 18, 29, 828000),
#   'efficiencies': [32.55004007796342,
#    30.22915815447378,
# ...

# %%
total_efficiencies = []
for seg in sepcific_focus_timer_records_list:
    efficiencies = seg['efficiencies']
    total_efficiencies += efficiencies

# %%
total_efficiencies
# Out:
# [42.93980099241144,
#  52.47654442972417,
#  53.5756687089743,
#  40.370281222546424,
#  63.35928736643706,
#  45.148810151436194,
#  32.92875551062562,
#  32.16874895459389,
#  29.03534555624791,
#  29.455512927561116,
#  36.556629911047736,
#  36.00721385531362,
#  32.55004007796342,
#  30.22915815447378,
#  29.601063367693943,
#  28.667986655354245,
#  27.996939402908875,
#  29.69971356288741,
#  27.680423809709414,
#  30.751910844786494,
#  28.57971034021648,
#  30.09169648514305,
#  28.215331762574298,
#  30.161223955316757,
#  30.05877986842369,
#  29.334507208359344,
#  28.570396611279968,
#  28.616134601486383,
#  31.94368681152276,
#  35.7166198491241,
#  33.14957277710478,
#  36.29673047357043,
#  32.12006297629799,
#  26.39067993637219,
#  34.35730548332685,
#  29.46215876166198,
#  26.60819031741163,
#  27.51601536571694,
#  35.16823625561171,
#  26.38924773987333,
#  28.761199997658416,
#  29.630719381175595,
#  25.583735531322816,
#  25.406366294147404,
# ...
